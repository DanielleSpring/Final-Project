# %% [markdown]
# # Cleaning of the Statics Canada - wages

# %%
#import dependencies
import pandas as pd

# %% [markdown]
# # Read in all wages files from Stats Canada for Male/Female, ages 25-54 & >55 years old

# %%
#File to Load Ontario Males 25-54 wages for 1997 to 2021
wages_male_25_data_to_load = "Raw Data CSV files/StatsCan_Male_25to54.csv"

# %%
# Create a DataFrame for Ontario Males 25-54 wages for 1997 to 2021
wages_male1_df = pd.read_csv(wages_male_25_data_to_load)

#display the data table for preview
wages_male1_df.head()
# Out:
#    REF_DATE      GEO        DGUID                     Wages  \
# 0      2017  Ontario  2016A000235  Average weekly wage rate
# 1      2018  Ontario  2016A000235  Average weekly wage rate
# 2      2019  Ontario  2016A000235  Average weekly wage rate
# 3      2020  Ontario  2016A000235  Average weekly wage rate
# 4      2021  Ontario  2016A000235  Average weekly wage rate
#
#           Type of work National Occupational Classification (NOC)    Sex  \
# 0  Full-time employees           Total employees, all occupations  Males
# 1  Full-time employees           Total employees, all occupations  Males
# 2  Full-time employees           Total employees, all occupations  Males
# 3  Full-time employees           Total employees, all occupations  Males
# 4  Full-time employees           Total employees, all occupations  Males
#
#         Age group              UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID  \
# 0  25 to 54 years  Current dollars      75         units          0
# 1  25 to 54 years  Current dollars      75         units          0
# 2  25 to 54 years  Current dollars      75         units          0
# 3  25 to 54 years  Current dollars      75         units          0
# 4  25 to 54 years  Current dollars      75         units          0
#
#         VECTOR   COORDINATE    VALUE STATUS  SYMBOL  TERMINATED  DECIMALS
# 0  v1063665269  7.3.2.1.2.3  1250.33    NaN     NaN         NaN         2
# 1  v1063665269  7.3.2.1.2.3  1283.03    NaN     NaN         NaN         2
# 2  v1063665269  7.3.2.1.2.3  1314.85    NaN     NaN         NaN         2
# 3  v1063665269  7.3.2.1.2.3  1388.65    NaN     NaN         NaN         2
# 4  v1063665269  7.3.2.1.2.3  1427.36    NaN     NaN         NaN         2

# %%
#File to Load Ontario Males >55 wages for 1997 to 2021
wages_male_55_data_to_load = "Raw Data CSV files/StatsCan_Male_55Older.csv"

# %%
# Create a DataFrame for Ontario Males >55 wages for 1997 to 2021
wages_male2_df = pd.read_csv(wages_male_55_data_to_load)

#display the data table for preview
wages_male2_df.head()
# Out:
#    REF_DATE      GEO        DGUID                     Wages  \
# 0      2017  Ontario  2016A000235  Average weekly wage rate
# 1      2018  Ontario  2016A000235  Average weekly wage rate
# 2      2019  Ontario  2016A000235  Average weekly wage rate
# 3      2020  Ontario  2016A000235  Average weekly wage rate
# 4      2021  Ontario  2016A000235  Average weekly wage rate
#
#           Type of work National Occupational Classification (NOC)    Sex  \
# 0  Full-time employees           Total employees, all occupations  Males
# 1  Full-time employees           Total employees, all occupations  Males
# 2  Full-time employees           Total employees, all occupations  Males
# 3  Full-time employees           Total employees, all occupations  Males
# 4  Full-time employees           Total employees, all occupations  Males
#
#            Age group              UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID  \
# 0  55 years and over  Current dollars      75         units          0
# 1  55 years and over  Current dollars      75         units          0
# 2  55 years and over  Current dollars      75         units          0
# 3  55 years and over  Current dollars      75         units          0
# 4  55 years and over  Current dollars      75         units          0
#
#         VECTOR   COORDINATE    VALUE STATUS  SYMBOL  TERMINATED  DECIMALS
# 0  v1063665270  7.3.2.1.2.4  1253.76    NaN     NaN         NaN         2
# 1  v1063665270  7.3.2.1.2.4  1278.24    NaN     NaN         NaN         2
# 2  v1063665270  7.3.2.1.2.4  1313.42    NaN     NaN         NaN         2
# 3  v1063665270  7.3.2.1.2.4  1417.76    NaN     NaN         NaN         2
# 4  v1063665270  7.3.2.1.2.4  1425.09    NaN     NaN         NaN         2

# %%
#File to Load Ontario Female 25-54 wages for 1997 to 2021
wages_female_25_data_to_load = "Raw Data CSV files/StatsCan_Wage_Female_25to54.csv"

# %%
# Create a DataFrame for Ontario Males 25-54 wages for 1997 to 2021
wages_female1_df = pd.read_csv(wages_female_25_data_to_load)

#display the data table for preview
wages_female1_df.head()
# Out:
#    REF_DATE      GEO        DGUID                     Wages  \
# 0      2017  Ontario  2016A000235  Average weekly wage rate
# 1      2018  Ontario  2016A000235  Average weekly wage rate
# 2      2019  Ontario  2016A000235  Average weekly wage rate
# 3      2020  Ontario  2016A000235  Average weekly wage rate
# 4      2021  Ontario  2016A000235  Average weekly wage rate
#
#           Type of work National Occupational Classification (NOC)      Sex  \
# 0  Full-time employees           Total employees, all occupations  Females
# 1  Full-time employees           Total employees, all occupations  Females
# 2  Full-time employees           Total employees, all occupations  Females
# 3  Full-time employees           Total employees, all occupations  Females
# 4  Full-time employees           Total employees, all occupations  Females
#
#         Age group              UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID  \
# 0  25 to 54 years  Current dollars      75         units          0
# 1  25 to 54 years  Current dollars      75         units          0
# 2  25 to 54 years  Current dollars      75         units          0
# 3  25 to 54 years  Current dollars      75         units          0
# 4  25 to 54 years  Current dollars      75         units          0
#
#         VECTOR   COORDINATE    VALUE STATUS  SYMBOL  TERMINATED  DECIMALS
# 0  v1063665273  7.3.2.1.3.3  1058.00    NaN     NaN         NaN         2
# 1  v1063665273  7.3.2.1.3.3  1092.20    NaN     NaN         NaN         2
# 2  v1063665273  7.3.2.1.3.3  1139.61    NaN     NaN         NaN         2
# 3  v1063665273  7.3.2.1.3.3  1205.10    NaN     NaN         NaN         2
# 4  v1063665273  7.3.2.1.3.3  1234.24    NaN     NaN         NaN         2

# %%
#File to Load Ontario Female > 55 wages for 1997 to 2021
wages_female_55_data_to_load = "Raw Data CSV files/StatsCan_Wage_Female_55Older.csv"

# %%
# Create a DataFrame for Ontario Males >55 wages for 1997 to 2021
wages_female2_df = pd.read_csv(wages_female_55_data_to_load)

#display the data table for preview
wages_female2_df.head()
# Out:
#    REF_DATE      GEO        DGUID                     Wages  \
# 0      2017  Ontario  2016A000235  Average weekly wage rate
# 1      2018  Ontario  2016A000235  Average weekly wage rate
# 2      2019  Ontario  2016A000235  Average weekly wage rate
# 3      2020  Ontario  2016A000235  Average weekly wage rate
# 4      2021  Ontario  2016A000235  Average weekly wage rate
#
#           Type of work National Occupational Classification (NOC)      Sex  \
# 0  Full-time employees           Total employees, all occupations  Females
# 1  Full-time employees           Total employees, all occupations  Females
# 2  Full-time employees           Total employees, all occupations  Females
# 3  Full-time employees           Total employees, all occupations  Females
# 4  Full-time employees           Total employees, all occupations  Females
#
#            Age group              UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID  \
# 0  55 years and over  Current dollars      75         units          0
# 1  55 years and over  Current dollars      75         units          0
# 2  55 years and over  Current dollars      75         units          0
# 3  55 years and over  Current dollars      75         units          0
# 4  55 years and over  Current dollars      75         units          0
#
#         VECTOR   COORDINATE    VALUE STATUS  SYMBOL  TERMINATED  DECIMALS
# 0  v1063665274  7.3.2.1.3.4  1038.15    NaN     NaN         NaN         2
# 1  v1063665274  7.3.2.1.3.4  1064.90    NaN     NaN         NaN         2
# 2  v1063665274  7.3.2.1.3.4  1100.28    NaN     NaN         NaN         2
# 3  v1063665274  7.3.2.1.3.4  1154.73    NaN     NaN         NaN         2
# 4  v1063665274  7.3.2.1.3.4  1187.72    NaN     NaN         NaN         2

# %% [markdown]
# # Create 1 Cosolidated Ontario Wages DataFrame

# %%
#Create Wage DataFrame - combine Male data
Ontario_Wages= wages_male1_df.append(wages_male2_df, ignore_index = True)
# Ontario_Wages.head()
Ontario_Wages.tail()
# Out:
#      REF_DATE      GEO        DGUID                     Wages  \
# 505      2017  Ontario  2016A000235  Average weekly wage rate
# 506      2018  Ontario  2016A000235  Average weekly wage rate
# 507      2019  Ontario  2016A000235  Average weekly wage rate
# 508      2020  Ontario  2016A000235  Average weekly wage rate
# 509      2021  Ontario  2016A000235  Average weekly wage rate
#
#             Type of work         National Occupational Classification (NOC)  \
# 505  Full-time employees  Labourers in processing, manufacturing and uti...
# 506  Full-time employees  Labourers in processing, manufacturing and uti...
# 507  Full-time employees  Labourers in processing, manufacturing and uti...
# 508  Full-time employees  Labourers in processing, manufacturing and uti...
# 509  Full-time employees  Labourers in processing, manufacturing and uti...
#
#        Sex          Age group              UOM  UOM_ID SCALAR_FACTOR  \
# 505  Males  55 years and over  Current dollars      75         units
# 506  Males  55 years and over  Current dollars      75         units
# 507  Males  55 years and over  Current dollars      75         units
# 508  Males  55 years and over  Current dollars      75         units
# 509  Males  55 years and over  Current dollars      75         units
#
#      SCALAR_ID       VECTOR    COORDINATE   VALUE STATUS  SYMBOL  TERMINATED  \
# 505          0  v1063665870  7.3.2.51.2.4  712.27    NaN     NaN         NaN
# 506          0  v1063665870  7.3.2.51.2.4  768.42    NaN     NaN         NaN
# 507          0  v1063665870  7.3.2.51.2.4  783.01    NaN     NaN         NaN
# 508          0  v1063665870  7.3.2.51.2.4  758.46    NaN     NaN         NaN
# 509          0  v1063665870  7.3.2.51.2.4  847.31    NaN     NaN         NaN
#
#      DECIMALS
# 505         2
# 506         2
# 507         2
# 508         2
# 509         2

# %%
# Add female 25-54 data
Ontario_Wages= Ontario_Wages.append(wages_female1_df, ignore_index = True)
Ontario_Wages.tail()
# Out:
#      REF_DATE      GEO        DGUID                     Wages  \
# 760      2017  Ontario  2016A000235  Average weekly wage rate
# 761      2018  Ontario  2016A000235  Average weekly wage rate
# 762      2019  Ontario  2016A000235  Average weekly wage rate
# 763      2020  Ontario  2016A000235  Average weekly wage rate
# 764      2021  Ontario  2016A000235  Average weekly wage rate
#
#             Type of work         National Occupational Classification (NOC)  \
# 760  Full-time employees  Labourers in processing, manufacturing and uti...
# 761  Full-time employees  Labourers in processing, manufacturing and uti...
# 762  Full-time employees  Labourers in processing, manufacturing and uti...
# 763  Full-time employees  Labourers in processing, manufacturing and uti...
# 764  Full-time employees  Labourers in processing, manufacturing and uti...
#
#          Sex       Age group              UOM  UOM_ID SCALAR_FACTOR  \
# 760  Females  25 to 54 years  Current dollars      75         units
# 761  Females  25 to 54 years  Current dollars      75         units
# 762  Females  25 to 54 years  Current dollars      75         units
# 763  Females  25 to 54 years  Current dollars      75         units
# 764  Females  25 to 54 years  Current dollars      75         units
#
#      SCALAR_ID       VECTOR    COORDINATE   VALUE STATUS  SYMBOL  TERMINATED  \
# 760          0  v1063665873  7.3.2.51.3.3  618.12    NaN     NaN         NaN
# 761          0  v1063665873  7.3.2.51.3.3  665.37    NaN     NaN         NaN
# 762          0  v1063665873  7.3.2.51.3.3  694.23    NaN     NaN         NaN
# 763          0  v1063665873  7.3.2.51.3.3  668.01    NaN     NaN         NaN
# 764          0  v1063665873  7.3.2.51.3.3  697.58    NaN     NaN         NaN
#
#      DECIMALS
# 760         2
# 761         2
# 762         2
# 763         2
# 764         2

# %%
Ontario_Wages= Ontario_Wages.append(wages_female2_df, ignore_index = True)
Ontario_Wages.tail()
# Out:
#       REF_DATE      GEO        DGUID                     Wages  \
# 1015      2017  Ontario  2016A000235  Average weekly wage rate
# 1016      2018  Ontario  2016A000235  Average weekly wage rate
# 1017      2019  Ontario  2016A000235  Average weekly wage rate
# 1018      2020  Ontario  2016A000235  Average weekly wage rate
# 1019      2021  Ontario  2016A000235  Average weekly wage rate
#
#              Type of work         National Occupational Classification (NOC)  \
# 1015  Full-time employees  Labourers in processing, manufacturing and uti...
# 1016  Full-time employees  Labourers in processing, manufacturing and uti...
# 1017  Full-time employees  Labourers in processing, manufacturing and uti...
# 1018  Full-time employees  Labourers in processing, manufacturing and uti...
# 1019  Full-time employees  Labourers in processing, manufacturing and uti...
#
#           Sex          Age group              UOM  UOM_ID SCALAR_FACTOR  \
# 1015  Females  55 years and over  Current dollars      75         units
# 1016  Females  55 years and over  Current dollars      75         units
# 1017  Females  55 years and over  Current dollars      75         units
# 1018  Females  55 years and over  Current dollars      75         units
# 1019  Females  55 years and over  Current dollars      75         units
#
#       SCALAR_ID       VECTOR    COORDINATE   VALUE STATUS  SYMBOL  TERMINATED  \
# 1015          0  v1063665874  7.3.2.51.3.4  612.71    NaN     NaN         NaN
# 1016          0  v1063665874  7.3.2.51.3.4  657.11    NaN     NaN         NaN
# 1017          0  v1063665874  7.3.2.51.3.4  667.23    NaN     NaN         NaN
# 1018          0  v1063665874  7.3.2.51.3.4  697.39    NaN     NaN         NaN
# 1019          0  v1063665874  7.3.2.51.3.4  688.87    NaN     NaN         NaN
#
#       DECIMALS
# 1015         2
# 1016         2
# 1017         2
# 1018         2
# 1019         2

# %%
#review data types
Ontario_Wages.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 19 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   REF_DATE                                    1020 non-null   int64
#  1   GEO                                         1020 non-null   object
#  2   DGUID                                       1020 non-null   object
#  3   Wages                                       1020 non-null   object
#  4   Type of work                                1020 non-null   object
#  5   National Occupational Classification (NOC)  1020 non-null   object
#  6   Sex                                         1020 non-null   object
#  7   Age group                                   1020 non-null   object
#  8   UOM                                         1020 non-null   object
#  9   UOM_ID                                      1020 non-null   int64
#  10  SCALAR_FACTOR                               1020 non-null   object
#  11  SCALAR_ID                                   1020 non-null   int64
#  12  VECTOR                                      1020 non-null   object
#  13  COORDINATE                                  1020 non-null   object
#  14  VALUE                                       924 non-null    float64
#  15  STATUS                                      96 non-null     object
#  16  SYMBOL                                      0 non-null      float64
#  17  TERMINATED                                  0 non-null      float64
#  18  DECIMALS                                    1020 non-null   int64
# dtypes: float64(3), int64(4), object(12)
# memory usage: 151.5+ KB

# %%
# Drop null value, not required columns Status, Symbol and Terminated
Ontario_Wages.drop(columns=['UOM','Type of work','DECIMALS','DGUID','UOM_ID','SCALAR_FACTOR', 'SCALAR_ID','VECTOR','COORDINATE','STATUS','SYMBOL','TERMINATED'], inplace=True)

# %%
Ontario_Wages.columns
# Out:
# Index(['REF_DATE', 'GEO', 'Wages',
#        'National Occupational Classification (NOC)', 'Sex', 'Age group',
#        'VALUE'],
#       dtype='object')

# %%
#Review Datatypes
Ontario_Wages.dtypes
# Out:
# REF_DATE                                        int64
# GEO                                            object
# Wages                                          object
# National Occupational Classification (NOC)     object
# Sex                                            object
# Age group                                      object
# VALUE                                         float64
# dtype: object

# %%
#Change Wages to numeric
# Use pd.to_numeric() method to convert the datatype of the Amount column
# df['Amount'] = pd.to_numeric(df['Amount'])
Ontario_Wages['VALUE'] = Ontario_Wages['VALUE'].astype(str). astype(float)

# %%
#find null values
for column in Ontario_Wages.columns:
    print(f"Column {column} has {Ontario_Wages[column].isnull().sum()}null values")
# Out:
# Column REF_DATE has 0null values
# Column GEO has 0null values
# Column Wages has 0null values
# Column National Occupational Classification (NOC) has 0null values
# Column Sex has 0null values
# Column Age group has 0null values
# Column VALUE has 96null values

# %%
# #review rows with null values - gender
# Null_Wage=Ontario_Wages[Ontario_Wages['weekly_wage'].isnull()]
# gender_split=Null_Wage.groupby('gender').count()
# gender_split

# %%
# #review rows with null values - noc
# Null_Wage=Ontario_Wages[Ontario_Wages['weekly_wage'].isnull()]
# #need to figure out how to see gender by no for the nan values

# %% [markdown]
# # Rename Ontario Wages column headers

# %%
# Rename the columns in the sunshine_data DataFrame.### changed to match 2020 data
Ontario_Wages.rename({'REF_DATE':'year',
                         'GEO':'province',
                         'Wages':'wage_frequency',
                         'National Occupational Classification (NOC)':'noc',
                         'Sex': 'gender',
                         'Age group':'age_group',
                         'VALUE':'weekly_wage'
                    }, axis='columns', inplace=True)

# %%
# Export to csv 
Ontario_Wages.to_csv("Clean_Ontario_Wages.csv", index=False)
Ontario_Wages.head()
# Out:
#    year province            wage_frequency                               noc  \
# 0  2017  Ontario  Average weekly wage rate  Total employees, all occupations
# 1  2018  Ontario  Average weekly wage rate  Total employees, all occupations
# 2  2019  Ontario  Average weekly wage rate  Total employees, all occupations
# 3  2020  Ontario  Average weekly wage rate  Total employees, all occupations
# 4  2021  Ontario  Average weekly wage rate  Total employees, all occupations
#
#   gender       age_group  weekly_wage
# 0  Males  25 to 54 years      1250.33
# 1  Males  25 to 54 years      1283.03
# 2  Males  25 to 54 years      1314.85
# 3  Males  25 to 54 years      1388.65
# 4  Males  25 to 54 years      1427.36

# %%
Ontario_Wages.dtypes
# Out:
# year                int64
# province           object
# wage_frequency     object
# noc                object
# gender             object
# age_group          object
# weekly_wage       float64
# dtype: object

# %% [markdown]
# # Cleaning of the Statics Canada - CPI

# %%
#File to Load Ontario Males 25-54 wages for 1997 to 2021
cpi_data_to_load = "Raw Data CSV files/OntarioCPI_databaseLoadingData.csv"

# %%
# Create a DataFrame for Ontario Males 25-54 wages for 1997 to 2021
cpi_df = pd.read_csv(cpi_data_to_load)

#display the data table for preview
cpi_df.tail()
# Out:
#      REF_DATE      GEO        DGUID Products and product groups       UOM  \
# 370      2016  Ontario  2016A000235                    Services  2002=100
# 371      2017  Ontario  2016A000235                    Services  2002=100
# 372      2018  Ontario  2016A000235                    Services  2002=100
# 373      2019  Ontario  2016A000235                    Services  2002=100
# 374      2020  Ontario  2016A000235                    Services  2002=100
#
#      UOM_ID SCALAR_FACTOR  SCALAR_ID     VECTOR  COORDINATE  VALUE  STATUS  \
# 370      17         units          0  v41694341      14.282  140.6     NaN
# 371      17         units          0  v41694341      14.282  144.6     NaN
# 372      17         units          0  v41694341      14.282  148.9     NaN
# 373      17         units          0  v41694341      14.282  152.4     NaN
# 374      17         units          0  v41694341      14.282  154.6     NaN
#
#      SYMBOL  TERMINATED  DECIMALS
# 370     NaN         NaN         1
# 371     NaN         NaN         1
# 372     NaN         NaN         1
# 373     NaN         NaN         1
# 374     NaN         NaN         1

# %%
#Review data types
cpi_df.dtypes
# Out:
# REF_DATE                         int64
# GEO                             object
# DGUID                           object
# Products and product groups     object
# UOM                             object
# UOM_ID                           int64
# SCALAR_FACTOR                   object
# SCALAR_ID                        int64
# VECTOR                          object
# COORDINATE                     float64
# VALUE                          float64
# STATUS                         float64
# SYMBOL                         float64
# TERMINATED                     float64
# DECIMALS                         int64
# dtype: object

# %%
#find null values
for column in cpi_df.columns:
    print(f"Column {column} has {cpi_df[column].isnull().sum()}null values")
# Out:
# Column REF_DATE has 0null values
# Column GEO has 0null values
# Column DGUID has 0null values
# Column Products and product groups has 0null values
# Column UOM has 0null values
# Column UOM_ID has 0null values
# Column SCALAR_FACTOR has 0null values
# Column SCALAR_ID has 0null values
# Column VECTOR has 0null values
# Column COORDINATE has 0null values
# Column VALUE has 0null values
# Column STATUS has 375null values
# Column SYMBOL has 375null values
# Column TERMINATED has 375null values
# Column DECIMALS has 0null values

# %%
# Drop null value, not required columns Status, Symbol and Terminated
cpi_df.drop(columns=['UOM','DECIMALS','DGUID','UOM_ID','SCALAR_FACTOR', 'SCALAR_ID','VECTOR','COORDINATE','STATUS','SYMBOL','TERMINATED'], inplace=True)

# %%
# Rename the columns in the sunshine_data DataFrame.### changed to match 2020 data
cpi_df.rename({'REF_DATE':'year',
                         'GEO':'province',
                         'Products and product groups':'product_groups',
                         'VALUE':'CPI'
                    }, axis='columns', inplace=True)

# %%
cpi_df.columns
# Out:
# Index(['year', 'province', 'product_groups', 'CPI'], dtype='object')

# %%
cpi_df.dtypes
# Out:
# year                int64
# province           object
# product_groups     object
# CPI               float64
# dtype: object

# %%
# Export to csv 
cpi_df.to_csv("Clean_CPI.csv", index=False)
cpi_df.head()
# Out:
#    year province product_groups   CPI
# 0  1996  Ontario      All-items  88.2
# 1  1997  Ontario      All-items  89.8
# 2  1998  Ontario      All-items  90.6
# 3  1999  Ontario      All-items  92.4
# 4  2000  Ontario      All-items  95.1
